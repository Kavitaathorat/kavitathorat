# %%
#Day-21 To_Do app
#Task-To_Do app(Advanced features)

def load_tasks(filename="tasks.txt"):
    
    try:
        with open(filename, "r") as file:
            tasks = file.readlines()
            return [task.strip() for task in tasks]
    except FileNotFoundError:
        return []

def save_tasks(tasks, filename="tasks.txt"):

    with open(filename, "w") as file:
        for task in tasks:
            file.write(task + "\n")

def display_tasks(tasks):
    
    if not tasks:
        print("No tasks available.")
    else:
        print("Your Tasks:")
        for idx, task in enumerate(tasks, 1):
            print(f"{idx}. {task}")

def delete_task(tasks):
    
    display_tasks(tasks)
    try:
        idx = int(input("Enter task number to delete: ")) - 1
        if 0 <= idx < len(tasks):
            removed = tasks.pop(idx)
            print(f"Deleted task: {removed}")
        else:
            print("Invalid task number.")
    except ValueError:
        print("Please enter a valid number.")

def main():
    tasks = load_tasks()
    
    while True:
        print("\n1. Add Task")
        print("2. View Tasks")
        print("3. Delete Task")
        print("4. Exit")
        
        choice = input("Enter your choice: ")
        
        if choice == "1":
            task = input("Enter task description: ")
            tasks.append(task)
            print("Task added.")
        elif choice == "2":
            display_tasks(tasks)
        elif choice == "3":
            delete_task(tasks)
        elif choice == "4":
            save_tasks(tasks)
            print("Tasks saved. Exiting...")
            break
        else:
            print("Invalid choice. Try again.")

if __name__ == "__main__":
    main()
# Out:
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice:  1
# Enter task description:  Finish project task
# Task added.
#
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice:  2
# Your Tasks:
# 1. Finish project task
#
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice:  3
# Your Tasks:
# 1. Finish project task
# Enter task number to delete:  1
# Deleted task: Finish project task
#
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice:  4
# Tasks saved. Exiting...
