# %%
#Day-11 Dictionary
#Task:-Create dic with name,age,city,course;print each value via its key

student={
    "name":"Kavita",
    "age":"22",
    "city":"Ahilyanagar",
    "course":"Python Internship"}
print("Name:",student["name"])
print("Age:",student["age"])
print("City:",student["city"])
print("Course:",student["course"])
# Out:
# Name: Kavita
# Age: 22
# City: Ahilyanagar
# Course: Python Internship

# %%
#Day-12 Functions
#Task-Create a function to calculate area of rectangle using user input.

def area(length,width):
         return length*width

l=int(input("Enter length:"))
w=int(input("Enter width:"))
print("Area of rectangle:",area(l,w))
# Out:
# Enter length: 87987
# Enter width: 568998
# Area of rectangle: 50064427026
