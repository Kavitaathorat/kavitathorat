# %%
#Day-13
#Task-Write name,age,city,course into student.txt.

file=open("student.txt","w")
file.write("Name:Shravan\n")
file.write("Age:22\n")
file.write("City:Nashik\n")
file.write("Course:MBA")
file.close()

# %%
#Day-14
#Task-Read that file,print content.

file=open("student.txt","r")
data=file.read()
print("File Content:")
print(data)
file.close()
# Out:
# File Content:
# Name:Shravan
# Age:22
# City:Nashik
# Course:MBA

# %%
#Day-15
#Task-Create class Student with name,age,city,make object;print details.

class Student:
    name="Shravan"
    age=22
    city="Pune"
s1=Student()
print("Name:",s1.name)
print("Age:",s1.age)
print("City:",s1.city)
# Out:
# Name: Shravan
# Age: 22
# City: Pune
