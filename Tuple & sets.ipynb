# %%
#Day-9 Tuple
#Task:-Create a tuple of 5 subjects and print:
#.All subjects
#.First subject
#.Last subject


subjects=("AI","DSA","Math","English","Computer")
print("All Subjects:",subjects)
print("First Subjects:",subjects[0])
print("Last Subjects:",subjects[-1])
# Out:
# All Subjects: ('AI', 'DSA', 'Math', 'English', 'Computer')
# First Subjects: AI
# Last Subjects: Computer

# %%
#Day-10
#Task:-Create a program to remove duplicate numbers usin sets.


n=[1,2,3,4,5,6,7,5,4,5,6]
unique_no=set(n)
print("unnique values:",unique_no)
# Out:
# unnique values: {1, 2, 3, 4, 5, 6, 7}
